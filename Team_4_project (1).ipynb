# %%
# !pip install scipy

# %%
# !pip install statsmodels

# %%
#import libraries
import numpy as np
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm

# %%
#upload csv file
df=pd.read_csv("/content/electricity.csv")
df.head(18)
# Out:
#       Year     Month   Bill Date        Amount  Unnamed: 4 Calculation Table  \
# 0   2020.0     April  16-04-2020    ? 1,283.0          NaN     Total Average
# 1   2020.0      June  14-06-2020    ? 5,419.0          NaN             Total
# 2   2020.0    August  14-08-2020    ? 7,284.0          NaN               Min
# 3   2020.0   October  11-10-2020   ? 10,741.0          NaN               Max
# 4   2020.0  December  05-12-2020      ? 375.0          NaN               NaN
# 5   2021.0  February  14-02-2021    ? 2,074.0          NaN               NaN
# 6   2021.0     April  10-04-2021    ? 1,225.0          NaN               NaN
# 7   2021.0      June  05-06-2021    ? 4,869.0          NaN               NaN
# 8   2021.0    August  06-08-2021   ? 14,113.0          NaN               NaN
# 9   2021.0   October  14-10-2021   ? 10,059.0          NaN               NaN
# 10  2021.0  December  10-10-2021    ? 1,423.0          NaN               NaN
# ...

# %%
#saving the csv file
data=df.to_csv("/content/electricity.csv")

# %%
#creating year and amount columns
column=['Year','Amount']
df_req=df[column]
df_req
# Out:
#       Year        Amount
# 0   2020.0    ? 1,283.0
# 1   2020.0    ? 5,419.0
# 2   2020.0    ? 7,284.0
# 3   2020.0   ? 10,741.0
# 4   2020.0      ? 375.0
# 5   2021.0    ? 2,074.0
# 6   2021.0    ? 1,225.0
# 7   2021.0    ? 4,869.0
# 8   2021.0   ? 14,113.0
# 9   2021.0   ? 10,059.0
# 10  2021.0    ? 1,423.0
# 11  2022.0    ? 1,855.0
# 12  2022.0    ? 1,335.0
# 13  2022.0   ? 12,076.0
# 14  2022.0   ? 15,359.0
# 15  2022.0   ? 14,502.0
# 16  2022.0    ? 3,247.0
# 17  2023.0    ? 3,268.0
# 18     NaN           NaN
# 19     NaN           NaN
# 20     NaN           NaN
# 21     NaN           NaN
# 22     NaN           NaN

# %%
#dropping null values
df1=df_req.dropna()

# %%
df1
# Out:
#       Year        Amount
# 0   2020.0    ? 1,283.0
# 1   2020.0    ? 5,419.0
# 2   2020.0    ? 7,284.0
# 3   2020.0   ? 10,741.0
# 4   2020.0      ? 375.0
# 5   2021.0    ? 2,074.0
# 6   2021.0    ? 1,225.0
# 7   2021.0    ? 4,869.0
# 8   2021.0   ? 14,113.0
# 9   2021.0   ? 10,059.0
# 10  2021.0    ? 1,423.0
# 11  2022.0    ? 1,855.0
# 12  2022.0    ? 1,335.0
# 13  2022.0   ? 12,076.0
# 14  2022.0   ? 15,359.0
# 15  2022.0   ? 14,502.0
# 16  2022.0    ? 3,247.0
# 17  2023.0    ? 3,268.0

# %%
#generate sample data
np.random.seed(0)
df1 = pd.DataFrame({
    'Year': np.random.choice(['2020', '2021', '2022'],size=18),
    'Amount':np.random.normal(loc=10, scale=2, size=18)#loc=>mean,scale=>standard deviation
})
print(df1)
# Out:
#     Year     Amount
# 0   2020   9.058458
# 1   2021  11.946032
# 2   2020   7.443702
# 3   2021  12.874741
# 4   2021   9.844591
# 5   2022  12.179260
# 6   2020  10.193085
# 7   2022  12.837334
# 8   2020  12.336546
# 9   2020  11.894372
# 10  2020  12.170974
# 11  2022  14.764449
# 12  2021   9.187953
# 13  2022  10.532891
# 14  2022   7.288573
# 15  2020   9.771795
# 16  2021   8.311538
# 17  2021  11.411282

# %%
#claculate mean amount for each year
mean_score_per_group = df1.groupby('Year')['Amount'].mean()
print(mean_score_per_group)
# Out:
# Year
# 2020    10.409847
# 2021    10.596023
# 2022    11.520501
# Name: Amount, dtype: float64

# %%
 #generate random year selections
choices = ['2020', '2021', '2022']
size = 18
year_column = np.random.choice(choices, size=size)
print(year_column)
# Out:
# ['2021' '2022' '2020' '2021' '2022' '2020' '2022' '2020' '2021' '2022'
#  '2022' '2021' '2020' '2021' '2021' '2020' '2022' '2022']

# %%
#calculate amount values
mean = 10
std = 2
size = 18
Amount_values = mean + std * np.random.randn(size)
print(Amount_values)
# Out:
# [ 9.97531037 10.08424298 13.91859178  9.60314861 10.66106881  7.12834319
#  10.05505663 12.24120931  9.55192244  9.15963322 11.99965939 10.8620683
#   8.69817426  7.00251923  7.53873006 10.38801438  8.00323529  9.26472479]

# %%
# hypothesis testing (t-test)
group_A = df1[df1['Year'] == '2020']['Amount']
group_B = df1[df1['Year'] == '2021']['Amount']
t_stat, p_value =stats.ttest_ind(group_A, group_B)
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -0.18616648409089434
# p-value: 0.8557029463822119

# %%
#prediction
if p_value < 0.05:
  print("reject the null hypothesis")
else:
  print("fail to reject the null hypothesis")
# Out:
# fail to reject the null hypothesis

# %%
#ANOVA (one-way ANOVA)
f_stat, p_value = stats.f_oneway(df1[df1['Year']== '2020']['Amount'],
                                 df1[df1['Year']== '2021']['Amount'],
                                 df1[df1['Year']== '2022']['Amount'])
print("F-statistic:",f_stat)
print("p-value:",p_value)
# Out:
# F-statistic: 0.43623602109638376
# p-value: 0.6544103539964587
