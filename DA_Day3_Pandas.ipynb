# %% [markdown]
# Pandas:
# -Used for data manipulation
# -Creates dataframes from excel,csv,txt,DBs
# -Dataframe (rows and coloumns  readable by python)
# -Data cleaning by dropping or replacing with mean
# -Visualize the data

# %%
import pandas as pd

# %% [markdown]
# Series

# %%
names=["neha","vyshu","divya","gopi","vasavi"]
index=[10,20,30,40,50]
ser1=pd.Series(names,index)
print(ser1)
# Out:
# 10      neha
# 20     vyshu
# 30     divya
# 40      gopi
# 50    vasavi
# dtype: object

# %% [markdown]
# Importing files
#
#
# *   for csv and txt:read_csv("file path")
# *   for excel:read_excel("file path")

# %%
df=pd.read_csv("/content/liver patients.csv")

# %%
df.head(10)
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
# 5   46    Male              1.8               0.7                   208
# 6   26  Female              0.9               0.2                   154
# 7   29  Female              0.9               0.3                   202
# 8   17    Male              0.9               0.3                   202
# 9   55    Male              0.7               0.2                   290
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# ...

# %%
df.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
df=pd.read_csv("/content/grades.txt",sep=",")

# %%
df.head()
# Out:
#   Names Initials SEM1 SEM2 SEM3 Grade
# 0                 Joe K 9.8 10 9.9 A+
# 1              Rajesh M 8.9 9.1 9.3 A
# 2              Kissan V 9.9 9.3 9.2 A
# 3                  Mary N 7.7 8 7.1 B
# 4               Jeen K 9.8 9.1 9.9 A+

# %%
dft=pd.read_excel("/content/iris.xlsx")

# %%
dft.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
dft=pd.read_excel("/content/iris.xlsx")
print(dft.describe)
# Out:
# <bound method NDFrame.describe of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
df=pd.read_csv("/content/liver patients.csv")
print(df.shape)#get the number of rows and columns
# Out:
# (583, 11)

# %%
df=pd.read_csv("/content/liver patients.csv")
print(df.shape[0])#Get the number of rows only
# Out:
# 583

# %%
df=pd.read_csv("/content/liver patients.csv")
print(df.shape[1])#get the number of columns only
# Out:
# 11

# %%
dft.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(dft.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
print(dft[2:6])#number of rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %% [markdown]
# Accesing data
#
#
# * loc-accepts column names and index
# * iloc-accepts only index

# %%
print(dft.loc[2:5,"species"])
# Out:
# 2    setosa
# 3    setosa
# 4    setosa
# 5    setosa
# Name: species, dtype: object

# %%
print(df.iloc[2:5])#rows of specified columns
# Out:
#    Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 2   62   Male              7.3               4.1                   490
# 3   58   Male              1.0               0.4                   182
# 4   72   Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 2      3.3                        0.89        1
# 3      3.4                        1.00        1
# 4      2.4                        0.40        1

# %%
print(dft.iloc[2:5, :3]) #iloc[row range,column range]=>index
# Out:
#    sepal_length  sepal_width  petal_length
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5
# 4           5.0          3.6           1.4

# %%
dft=pd.read_csv("/content/grades_withnulls.csv")
dft.head(16)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   NaN     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   NaN   9.1   9.9    A+       1
# 9   Rajini        M   NaN   9.1   9.3     A       0
# 10   Kiran        V   NaN   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0

# %%
dft.isnull()
# Out:
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# 15  False     False  False  False  False  False   False
# ...

# %%
dft.isnull().sum()
# Out:
# Names       0
# Initials    0
# SEM1        3
# SEM2        0
# SEM3        1
# Grade       0
# Placed      0
# dtype: int64

# %% [markdown]
# Dropping

# %%
dft.isnull().sum().sum()#to view total nulls
# Out:
# 4

# %%
dft.dropna()#dropping all the rows with nulls
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dftc=dft.dropna()

# %%
dftc
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dft.fillna(5)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %%
dftc1=dft.fillna(5)
dftc1
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 3     Mary        N   7.7   8.0   5.0     B       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 8     Jess        K   5.0   9.1   9.9    A+       1
# 9   Rajini        M   5.0   9.1   9.3     A       0
# 10   Kiran        V   5.0   9.3   9.2     A       0
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0

# %% [markdown]
# Cleaning with mean

# %%
m=dft['SEM3'].mean()
print(m)
# Out:
# 9.100000000000001

# %%
dftc2=df.fillna(m)
print(dftc2)
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %%
dropped=dftc2.drop_duplicates()
print( dropped )
# Out:
#    Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                       Joe K 9.8 10 9.9 A+ 1
# 1                   Rajesh M 8.9 9.1 9.3 A 1
# 2                     Kissan V 9.9 9.8 10 A 0
# 3                        Mary N 7.7 8 NaN B 0
# 4                     Jeen K 9.8 9.1 9.9 A+ 1
# 5                       Raj M 8.9 9.1 9.3 A 1
# 6                      Hassan V 9.9 9 9.2 A 1
# 7                        Mari N 7.7 8 7.1 B 1
# 8                     Jess K NaN 9.1 9.9 A+ 1
# 9                    Rajini M NaN 9.1 9.3 A 0
# 10                    Kiran V NaN 9.3 9.2 A 0
# 11                       Maya N 7.7 8 7.1 B 0
# 12                   Jolin K 9.8 9.1 9.9 A+ 1
# 13                   Rajesh M 8.9 9.1 9.3 A 1
# 14                      Riya M 9.3 9.9 10 A 1
# 15                     Sana V 9.9 9.3 9.2 A 0
# 16                         Mark N 7.7 8 7 B 0

# %% [markdown]
# Columns

# %%
dft.rename(columns={"Grade" :"GPA"})#dft.rename(columns= {old:new})
# Out:
#      Names Initials  SEM1  SEM2  SEM3 GPA  Placed
# 0      Joe        K   9.8  10.0   9.9  A+       1
# 1   Rajesh        M   8.9   9.1   9.3   A       1
# 2   Kissan        V   9.9   9.8  10.0   A       0
# 3     Mary        N   7.7   8.0   NaN   B       0
# 4     Jeen        K   9.8   9.1   9.9  A+       1
# 5      Raj        M   8.9   9.1   9.3   A       1
# 6   Hassan        V   9.9   9.0   9.2   A       1
# 7     Mari        N   7.7   8.0   7.1   B       1
# 8     Jess        K   NaN   9.1   9.9  A+       1
# 9   Rajini        M   NaN   9.1   9.3   A       0
# 10   Kiran        V   NaN   9.3   9.2   A       0
# 11    Maya        N   7.7   8.0   7.1   B       0
# 12   Jolin        K   9.8   9.1   9.9  A+       1
# 13  Rajesh        M   8.9   9.1   9.3   A       1
# 14    Riya        M   9.3   9.9  10.0   A       1
# 15    Sana        V   9.9   9.3   9.2   A       0
# 16    Mark        N   7.7   8.0   7.0   B       0

# %%
dftc2.rename(columns={"Grade" :"GPA"},inplace = True)#dft.rename(columns= {old:new})d

# %%
dftc2.head()
# Out:
#   Names Initials SEM1 SEM2 SEM3 Grade Placed
# 0                      Joe K 9.8 10 9.9 A+ 1
# 1                  Rajesh M 8.9 9.1 9.3 A 1
# 2                    Kissan V 9.9 9.8 10 A 0
# 3                       Mary N 7.7 8 NaN B 0
# 4                    Jeen K 9.8 9.1 9.9 A+ 1

# %%
dft['Avg_score'] = (dft['SEM1'] + dft['SEM2'] + dft['SEM3'])/3#DF['NEWCOL']=values
dft.head()
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed  Avg_score
# 0     Joe        K   9.8  10.0   9.9    A+       1        9.9
# 1  Rajesh        M   8.9   9.1   9.3     A       1        9.1
# 2  Kissan        V   9.9   9.8  10.0     A       0        9.9
# 3    Mary        N   7.7   8.0   NaN     B       0        NaN
# 4    Jeen        K   9.8   9.1   9.9    A+       1        9.6

# %%
dft[['SEM1','SEM2']].plot.line()
# Out:
# <Axes: >

# %%
dft.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
import seaborn as sns

# %%
pl=sns.lineplot(x='Names',y='SEM1',data=dft)

# %%
sns.relplot(data=dft,x="SEM2",y="SEM1",col="Names")

# %% [markdown]
# Problem:
# *   load diabetes.csv
#
# *    create a relplot index in x-axis,age in y-axis and class as columns

# %%
ds=pd.read_csv("/content/diabetcsv.csv")

# %%
ds.head()
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive

# %%
H=ds.columns
print(H)
# Out:
# Index(['preg', 'plas', 'pres', 'skin', 'insu', 'mass', 'pedi', 'age', 'class'], dtype='object')

# %%
ds['index']=range(1,769)#creating indexes
ds
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      1
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      2
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      3
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      4
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      5
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    764
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    765
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    766
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    767
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    768
#
# [768 rows x 10 columns]

# %%
sns.relplot(data=ds,x="index",y="age",col="class")

# %%
import seaborn as sns

# %%
tips=sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fmri=sns.load_dataset("fmri")

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
dowjones=sns.load_dataset("dowjones")

# %%
dowjones.head()
# Out:
#         Date  Price
# 0 1914-12-01  55.00
# 1 1915-01-01  56.55
# 2 1915-02-01  56.00
# 3 1915-03-01  58.30
# 4 1915-04-01  66.45

# %%
dots=sns.load_dataset("dots")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
healthexp=sns.load_dataset("healthexp")

# %%
healthexp.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %%
sns.relplot(data=tips,x="total_bill",y="tip")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="time")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="day")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="size")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="day",style="time")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="smoker",style="time",palette="dark")

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="day",style="time",palette="pastel")

# %%
sns.relplot(data=dowjones,x="Date",y="Price",kind="line")

# %%
sns.relplot(data=fmri,x="timepoint",y="signal")

# %%
sns.catplot(data=tips,x="total_bill",y='day')

# %%
sns.catplot(data=fmri,x="region",y='timepoint')

# %%
sns.catplot(data=fmri,x="region",y='timepoint',kind="violin")

# %%
sns.catplot(data=tips,y="total_bill",x='time',kind="violin",hue="smoker")

# %% [markdown]
# Linear fit
#
#
# *   lmplot and create a function
# *   plotting the dataset
# *   fitting/finding a pefect line
# *   prediction

# %%
sns.lmplot(x="size",y="tip",data=tips);

# %%
sns.lmplot(x="signal",y="timepoint",data=fmri);
